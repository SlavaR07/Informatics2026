# %% [markdown]
# <a href="https://colab.research.google.com/github/SlavaR07/Informatics2026/blob/main/%D0%A2%D0%B8%D0%BF_1_(%D0%95%D0%93%D0%AD_%D0%98%D0%BD%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%82%D0%B8%D0%BA%D0%B0_2026).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2026-02-12 140951.png](data:image/png;base64,...)

# %% [markdown]
# Решение
#
#
# ![Снимок экрана 2026-02-12 140951.jpg](data:image/jpeg;base64,...)
